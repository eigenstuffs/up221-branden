# %%
import pandas as pd
import geopandas as gpd
import folium

# %% [markdown]
# Read and view tracts data, select important variables

# %%
tracts = gpd.read_file("tl_2020_06_tract.dbf")
tracts.head()
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /opt/conda/share/proj failed
#   STATEFP COUNTYFP TRACTCE        GEOID     NAME              NAMELSAD  MTFCC  \
# 0      06      029  004402  06029004402    44.02    Census Tract 44.02  G5020
# 1      06      047  000802  06047000802     8.02     Census Tract 8.02  G5020
# 2      06      085  501402  06085501402  5014.02  Census Tract 5014.02  G5020
# 3      06      005  000102  06005000102     1.02     Census Tract 1.02  G5020
# 4      06      029  004901  06029004901    49.01    Census Tract 49.01  G5020
#
#   FUNCSTAT      ALAND   AWATER     INTPTLAT      INTPTLON geometry
# 0        S    1865739        0  +35.5917343  -119.3337642     None
# 1        S    2321653        0  +37.3433591  -120.5854604     None
# 2        S     522620        0  +37.3453341  -121.8665169     None
# 3        S  456204155  7940832  +38.5496993  -120.2509786     None
# 4        S    1459379        0  +35.7837173  -119.2462266     None

# %%
tracts = tracts[['NAME', 'INTPTLAT', 'INTPTLON']]

# %%
tracts.head()
# Out:
#       NAME     INTPTLAT      INTPTLON
# 0    44.02  +35.5917343  -119.3337642
# 1     8.02  +37.3433591  -120.5854604
# 2  5014.02  +37.3453341  -121.8665169
# 3     1.02  +38.5496993  -120.2509786
# 4    49.01  +35.7837173  -119.2462266

# %% [markdown]
# Read ACS data, create function to extract tract number with regex

# %%
acs = gpd.read_file("ACSDP5Y2022.DP05-Data.csv")

# %%
acs.head()

import re

def extract_census_tract(text):
    match = re.search(r'\b\d{4}\.\d{2}\b', text)
    return match.group(0) if match else None

acs['NAME'] = acs['NAME'].apply(extract_census_tract)

# %%
acs.head()
# Out:
#       NAME                               DP05_0001E  \
# 0     None  Estimate!!SEX AND AGE!!Total population
# 1  1011.10                                     4014
# 2  1011.22                                     4164
# 3  1012.20                                     3481
# 4  1012.21                                     3756
#
#                                        DP05_0001M  \
# 0  Margin of Error!!SEX AND AGE!!Total population
# 1                                             473
# 2                                             822
# 3                                             467
# 4                                             687
#
#                                       DP05_0002E  \
# 0  Estimate!!SEX AND AGE!!Total population!!Male
# 1                                           1905
# 2                                           2098
# 3                                           1651
# 4                                           1966
#
#                                           DP05_0002M  \
# 0  Margin of Error!!SEX AND AGE!!Total population...
# 1                                                265
# 2                                                449
# 3                                                266
# 4                                                427
#
#                                         DP05_0003E  \
# 0  Estimate!!SEX AND AGE!!Total population!!Female
# 1                                             2109
# 2                                             2066
# 3                                             1830
# 4                                             1790
#
#                                           DP05_0003M  \
# 0  Margin of Error!!SEX AND AGE!!Total population...
# 1                                                326
# 2                                                432
# 3                                                282
# 4                                                382
#
#                                           DP05_0004E  \
# 0  Estimate!!SEX AND AGE!!Total population!!Sex r...
# 1                                               90.3
# 2                                              101.5
# 3                                               90.2
# 4                                              109.8
#
#                                           DP05_0004M  \
# 0  Margin of Error!!SEX AND AGE!!Total population...
# 1                                               16.1
# 2                                               15.5
# 3                                                 15
# 4                                               24.7
#
#                                           DP05_0005E  ...  \
# 0  Estimate!!SEX AND AGE!!Total population!!Under...  ...
# 1                                                141  ...
# 2                                                128  ...
# 3                                                135  ...
# 4                                                154  ...
#
#                                          DP05_0087PM  \
# 0  Percent Margin of Error!!HISPANIC OR LATINO AN...
# 1                                                2.8
# 2                                                2.8
# 3                                                1.1
# 4                                                1.9
#
#                     DP05_0088PE                                   DP05_0088PM  \
# 0  Percent!!Total housing units  Percent Margin of Error!!Total housing units
# 1                           (X)                                           (X)
# 2                           (X)                                           (X)
# 3                           (X)                                           (X)
# 4                           (X)                                           (X)
#
#                                          DP05_0089PE  \
# 0  Percent!!CITIZEN, VOTING AGE POPULATION!!Citiz...
# 1                                               3106
# 2                                               3252
# 3                                               2459
# 4                                               2224
#
#                                          DP05_0089PM  \
# 0  Percent Margin of Error!!CITIZEN, VOTING AGE P...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                          DP05_0090PE  \
# 0  Percent!!CITIZEN, VOTING AGE POPULATION!!Citiz...
# 1                                               46.5
# 2                                               52.4
# 3                                               46.8
# 4                                               54.9
#
#                                          DP05_0090PM  \
# 0  Percent Margin of Error!!CITIZEN, VOTING AGE P...
# 1                                                4.3
# 2                                                3.9
# 3                                                5.8
# 4                                                8.4
#
#                                          DP05_0091PE  \
# 0  Percent!!CITIZEN, VOTING AGE POPULATION!!Citiz...
# 1                                               53.5
# 2                                               47.6
# 3                                               53.2
# 4                                               45.1
#
#                                          DP05_0091PM geometry
# 0  Percent Margin of Error!!CITIZEN, VOTING AGE P...     None
# 1                                                4.3     None
# 2                                                3.9     None
# 3                                                5.8     None
# 4                                                8.4     None
#
# [5 rows x 366 columns]

# %%
tracts.head()
# Out:
#       NAME     INTPTLAT      INTPTLON
# 0    44.02  +35.5917343  -119.3337642
# 1     8.02  +37.3433591  -120.5854604
# 2  5014.02  +37.3453341  -121.8665169
# 3     1.02  +38.5496993  -120.2509786
# 4    49.01  +35.7837173  -119.2462266

# %% [markdown]
# Left-join the data (keep all observations in joined) by common variable NAME

# %%
joined = acs.merge(tracts, on='NAME', how='left')
joined.head()
# Out:
#       NAME                               DP05_0001E  \
# 0     None  Estimate!!SEX AND AGE!!Total population
# 1  1011.10                                     4014
# 2  1011.22                                     4164
# 3  1012.20                                     3481
# 4  1012.21                                     3756
#
#                                        DP05_0001M  \
# 0  Margin of Error!!SEX AND AGE!!Total population
# 1                                             473
# 2                                             822
# 3                                             467
# 4                                             687
#
#                                       DP05_0002E  \
# 0  Estimate!!SEX AND AGE!!Total population!!Male
# 1                                           1905
# 2                                           2098
# 3                                           1651
# 4                                           1966
#
#                                           DP05_0002M  \
# 0  Margin of Error!!SEX AND AGE!!Total population...
# 1                                                265
# 2                                                449
# 3                                                266
# 4                                                427
#
#                                         DP05_0003E  \
# 0  Estimate!!SEX AND AGE!!Total population!!Female
# 1                                             2109
# 2                                             2066
# 3                                             1830
# 4                                             1790
#
#                                           DP05_0003M  \
# 0  Margin of Error!!SEX AND AGE!!Total population...
# 1                                                326
# 2                                                432
# 3                                                282
# 4                                                382
#
#                                           DP05_0004E  \
# 0  Estimate!!SEX AND AGE!!Total population!!Sex r...
# 1                                               90.3
# 2                                              101.5
# 3                                               90.2
# 4                                              109.8
#
#                                           DP05_0004M  \
# 0  Margin of Error!!SEX AND AGE!!Total population...
# 1                                               16.1
# 2                                               15.5
# 3                                                 15
# 4                                               24.7
#
#                                           DP05_0005E  ...  \
# 0  Estimate!!SEX AND AGE!!Total population!!Under...  ...
# 1                                                141  ...
# 2                                                128  ...
# 3                                                135  ...
# 4                                                154  ...
#
#                                     DP05_0088PM  \
# 0  Percent Margin of Error!!Total housing units
# 1                                           (X)
# 2                                           (X)
# 3                                           (X)
# 4                                           (X)
#
#                                          DP05_0089PE  \
# 0  Percent!!CITIZEN, VOTING AGE POPULATION!!Citiz...
# 1                                               3106
# 2                                               3252
# 3                                               2459
# 4                                               2224
#
#                                          DP05_0089PM  \
# 0  Percent Margin of Error!!CITIZEN, VOTING AGE P...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                          DP05_0090PE  \
# 0  Percent!!CITIZEN, VOTING AGE POPULATION!!Citiz...
# 1                                               46.5
# 2                                               52.4
# 3                                               46.8
# 4                                               54.9
#
#                                          DP05_0090PM  \
# 0  Percent Margin of Error!!CITIZEN, VOTING AGE P...
# 1                                                4.3
# 2                                                3.9
# 3                                                5.8
# 4                                                8.4
#
#                                          DP05_0091PE  \
# 0  Percent!!CITIZEN, VOTING AGE POPULATION!!Citiz...
# 1                                               53.5
# 2                                               47.6
# 3                                               53.2
# 4                                               45.1
#
#                                          DP05_0091PM geometry     INTPTLAT  \
# 0  Percent Margin of Error!!CITIZEN, VOTING AGE P...     None          NaN
# 1                                                4.3     None  +34.2594737
# 2                                                3.9     None  +34.2677213
# 3                                                5.8     None  +34.2516083
# 4                                                8.4     None  +34.2543290
#
#        INTPTLON
# 0           NaN
# 1  -118.2929869
# 2  -118.2901465
# 3  -118.2816328
# 4  -118.2925767
#
# [5 rows x 368 columns]

# %% [markdown]
# Create geometry column from lon and lat columns

# %%
from shapely.geometry import Point

joined['geometry'] = joined.apply(lambda row: Point(row['INTPTLON'], row['INTPTLAT']), axis=1)
gdf = gpd.GeoDataFrame(joined, geometry='geometry')
gdf.set_crs(epsg=4326, inplace=True)
# Out:
#          NAME                               DP05_0001E  \
# 0        None  Estimate!!SEX AND AGE!!Total population
# 1     1011.10                                     4014
# 2     1011.22                                     4164
# 3     1012.20                                     3481
# 4     1012.21                                     3756
# ...       ...                                      ...
# 2552  9800.38                                        0
# 2553  9800.39                                        0
# 2554     None                                        0
# 2555     None                                        0
# 2556     None                                        0
#
#                                           DP05_0001M  \
# 0     Margin of Error!!SEX AND AGE!!Total population
# 1                                                473
# 2                                                822
# 3                                                467
# 4                                                687
# ...                                              ...
# 2552                                              13
# 2553                                              13
# 2554                                              13
# 2555                                              13
# 2556                                              13
#
#                                          DP05_0002E  \
# 0     Estimate!!SEX AND AGE!!Total population!!Male
# 1                                              1905
# 2                                              2098
# 3                                              1651
# 4                                              1966
# ...                                             ...
# 2552                                              0
# 2553                                              0
# 2554                                              0
# 2555                                              0
# 2556                                              0
#
#                                              DP05_0002M  \
# 0     Margin of Error!!SEX AND AGE!!Total population...
# 1                                                   265
# 2                                                   449
# 3                                                   266
# 4                                                   427
# ...                                                 ...
# 2552                                                 13
# 2553                                                 13
# 2554                                                 13
# 2555                                                 13
# 2556                                                 13
#
#                                            DP05_0003E  \
# 0     Estimate!!SEX AND AGE!!Total population!!Female
# 1                                                2109
# 2                                                2066
# 3                                                1830
# 4                                                1790
# ...                                               ...
# 2552                                                0
# 2553                                                0
# 2554                                                0
# 2555                                                0
# 2556                                                0
#
#                                              DP05_0003M  \
# 0     Margin of Error!!SEX AND AGE!!Total population...
# 1                                                   326
# 2                                                   432
# 3                                                   282
# 4                                                   382
# ...                                                 ...
# 2552                                                 13
# 2553                                                 13
# 2554                                                 13
# 2555                                                 13
# 2556                                                 13
#
#                                              DP05_0004E  \
# 0     Estimate!!SEX AND AGE!!Total population!!Sex r...
# 1                                                  90.3
# 2                                                 101.5
# 3                                                  90.2
# 4                                                 109.8
# ...                                                 ...
# 2552                                                  -
# 2553                                                  -
# 2554                                                  -
# 2555                                                  -
# 2556                                                  -
#
#                                              DP05_0004M  \
# 0     Margin of Error!!SEX AND AGE!!Total population...
# 1                                                  16.1
# 2                                                  15.5
# 3                                                    15
# 4                                                  24.7
# ...                                                 ...
# 2552                                                 **
# 2553                                                 **
# 2554                                                 **
# 2555                                                 **
# 2556                                                 **
#
#                                              DP05_0005E  ...  \
# 0     Estimate!!SEX AND AGE!!Total population!!Under...  ...
# 1                                                   141  ...
# 2                                                   128  ...
# 3                                                   135  ...
# 4                                                   154  ...
# ...                                                 ...  ...
# 2552                                                  0  ...
# 2553                                                  0  ...
# 2554                                                  0  ...
# 2555                                                  0  ...
# 2556                                                  0  ...
#
#                                        DP05_0088PM  \
# 0     Percent Margin of Error!!Total housing units
# 1                                              (X)
# 2                                              (X)
# 3                                              (X)
# 4                                              (X)
# ...                                            ...
# 2552                                           (X)
# 2553                                           (X)
# 2554                                           (X)
# 2555                                           (X)
# 2556                                           (X)
#
#                                             DP05_0089PE  \
# 0     Percent!!CITIZEN, VOTING AGE POPULATION!!Citiz...
# 1                                                  3106
# 2                                                  3252
# 3                                                  2459
# 4                                                  2224
# ...                                                 ...
# 2552                                                  0
# 2553                                                  0
# 2554                                                  0
# 2555                                                  0
# 2556                                                  0
#
#                                             DP05_0089PM  \
# 0     Percent Margin of Error!!CITIZEN, VOTING AGE P...
# 1                                                   (X)
# 2                                                   (X)
# 3                                                   (X)
# 4                                                   (X)
# ...                                                 ...
# 2552                                                (X)
# 2553                                                (X)
# 2554                                                (X)
# 2555                                                (X)
# 2556                                                (X)
#
#                                             DP05_0090PE  \
# 0     Percent!!CITIZEN, VOTING AGE POPULATION!!Citiz...
# 1                                                  46.5
# 2                                                  52.4
# 3                                                  46.8
# 4                                                  54.9
# ...                                                 ...
# 2552                                                  -
# 2553                                                  -
# 2554                                                  -
# 2555                                                  -
# 2556                                                  -
#
#                                             DP05_0090PM  \
# 0     Percent Margin of Error!!CITIZEN, VOTING AGE P...
# 1                                                   4.3
# 2                                                   3.9
# 3                                                   5.8
# 4                                                   8.4
# ...                                                 ...
# 2552                                                 **
# 2553                                                 **
# 2554                                                 **
# 2555                                                 **
# 2556                                                 **
#
#                                             DP05_0091PE  \
# 0     Percent!!CITIZEN, VOTING AGE POPULATION!!Citiz...
# 1                                                  53.5
# 2                                                  47.6
# 3                                                  53.2
# 4                                                  45.1
# ...                                                 ...
# 2552                                                  -
# 2553                                                  -
# 2554                                                  -
# 2555                                                  -
# 2556                                                  -
#
#                                             DP05_0091PM  \
# 0     Percent Margin of Error!!CITIZEN, VOTING AGE P...
# 1                                                   4.3
# 2                                                   3.9
# 3                                                   5.8
# 4                                                   8.4
# ...                                                 ...
# 2552                                                 **
# 2553                                                 **
# 2554                                                 **
# 2555                                                 **
# 2556                                                 **
#
#                          geometry     INTPTLAT      INTPTLON
# 0                     POINT EMPTY          NaN           NaN
# 1     POINT (-118.29299 34.25947)  +34.2594737  -118.2929869
# 2     POINT (-118.29015 34.26772)  +34.2677213  -118.2901465
# 3     POINT (-118.28163 34.25161)  +34.2516083  -118.2816328
# 4     POINT (-118.29258 34.25433)  +34.2543290  -118.2925767
# ...                           ...          ...           ...
# 2552  POINT (-118.37550 34.00107)  +34.0010705  -118.3754970
# 2553  POINT (-118.35086 34.13874)  +34.1387351  -118.3508573
# 2554                  POINT EMPTY          NaN           NaN
# 2555                  POINT EMPTY          NaN           NaN
# 2556                  POINT EMPTY          NaN           NaN
#
# [2557 rows x 368 columns]

# %%
gdf.head()
# Out:
#       NAME                               DP05_0001E  \
# 0     None  Estimate!!SEX AND AGE!!Total population
# 1  1011.10                                     4014
# 2  1011.22                                     4164
# 3  1012.20                                     3481
# 4  1012.21                                     3756
#
#                                        DP05_0001M  \
# 0  Margin of Error!!SEX AND AGE!!Total population
# 1                                             473
# 2                                             822
# 3                                             467
# 4                                             687
#
#                                       DP05_0002E  \
# 0  Estimate!!SEX AND AGE!!Total population!!Male
# 1                                           1905
# 2                                           2098
# 3                                           1651
# 4                                           1966
#
#                                           DP05_0002M  \
# 0  Margin of Error!!SEX AND AGE!!Total population...
# 1                                                265
# 2                                                449
# 3                                                266
# 4                                                427
#
#                                         DP05_0003E  \
# 0  Estimate!!SEX AND AGE!!Total population!!Female
# 1                                             2109
# 2                                             2066
# 3                                             1830
# 4                                             1790
#
#                                           DP05_0003M  \
# 0  Margin of Error!!SEX AND AGE!!Total population...
# 1                                                326
# 2                                                432
# 3                                                282
# 4                                                382
#
#                                           DP05_0004E  \
# 0  Estimate!!SEX AND AGE!!Total population!!Sex r...
# 1                                               90.3
# 2                                              101.5
# 3                                               90.2
# 4                                              109.8
#
#                                           DP05_0004M  \
# 0  Margin of Error!!SEX AND AGE!!Total population...
# 1                                               16.1
# 2                                               15.5
# 3                                                 15
# 4                                               24.7
#
#                                           DP05_0005E  ...  \
# 0  Estimate!!SEX AND AGE!!Total population!!Under...  ...
# 1                                                141  ...
# 2                                                128  ...
# 3                                                135  ...
# 4                                                154  ...
#
#                                     DP05_0088PM  \
# 0  Percent Margin of Error!!Total housing units
# 1                                           (X)
# 2                                           (X)
# 3                                           (X)
# 4                                           (X)
#
#                                          DP05_0089PE  \
# 0  Percent!!CITIZEN, VOTING AGE POPULATION!!Citiz...
# 1                                               3106
# 2                                               3252
# 3                                               2459
# 4                                               2224
#
#                                          DP05_0089PM  \
# 0  Percent Margin of Error!!CITIZEN, VOTING AGE P...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                          DP05_0090PE  \
# 0  Percent!!CITIZEN, VOTING AGE POPULATION!!Citiz...
# 1                                               46.5
# 2                                               52.4
# 3                                               46.8
# 4                                               54.9
#
#                                          DP05_0090PM  \
# 0  Percent Margin of Error!!CITIZEN, VOTING AGE P...
# 1                                                4.3
# 2                                                3.9
# 3                                                5.8
# 4                                                8.4
#
#                                          DP05_0091PE  \
# 0  Percent!!CITIZEN, VOTING AGE POPULATION!!Citiz...
# 1                                               53.5
# 2                                               47.6
# 3                                               53.2
# 4                                               45.1
#
#                                          DP05_0091PM  \
# 0  Percent Margin of Error!!CITIZEN, VOTING AGE P...
# 1                                                4.3
# 2                                                3.9
# 3                                                5.8
# 4                                                8.4
#
#                       geometry     INTPTLAT      INTPTLON
# 0                  POINT EMPTY          NaN           NaN
# 1  POINT (-118.29299 34.25947)  +34.2594737  -118.2929869
# 2  POINT (-118.29015 34.26772)  +34.2677213  -118.2901465
# 3  POINT (-118.28163 34.25161)  +34.2516083  -118.2816328
# 4  POINT (-118.29258 34.25433)  +34.2543290  -118.2925767
#
# [5 rows x 368 columns]

# %% [markdown]
# Rename columns to first row observations, drop first row

# %%
first_col = gdf.columns[0]
last_three_cols = gdf.columns[-3:]

new_column_names = {gdf.columns[i]: gdf.iloc[0, i] for i in range(1, len(gdf.columns) - 3)}
gdf = gdf.rename(columns=new_column_names)

# Restore the original names for the first and last three columns
gdf.columns = [first_col] + list(gdf.columns[1:-3]) + list(last_three_cols)

# Drop the first row
gdf = gdf.drop(gdf.index[0])

# Reset the index if needed
gdf = gdf.reset_index(drop=True)

# %%
gdf.head()
# Out:
#       NAME Percent!!SEX AND AGE!!Total population  \
# 0  1011.10                                   4014
# 1  1011.22                                   4164
# 2  1012.20                                   3481
# 3  1012.21                                   3756
# 4  1012.22                                   2808
#
#   Percent!!SEX AND AGE!!Total population!!Male  \
# 0                                         47.5
# 1                                         50.4
# 2                                         47.4
# 3                                         52.3
# 4                                         45.1
#
#   Percent!!SEX AND AGE!!Total population!!Female  \
# 0                                           52.5
# 1                                           49.6
# 2                                           52.6
# 3                                           47.7
# 4                                           54.9
#
#   Percent!!SEX AND AGE!!Total population!!Sex ratio (males per 100 females)  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#   Percent!!SEX AND AGE!!Total population!!Under 5 years  \
# 0                                                3.5
# 1                                                3.1
# 2                                                3.9
# 3                                                4.1
# 4                                                  1
#
#   Percent!!SEX AND AGE!!Total population!!5 to 9 years  \
# 0                                                3.3
# 1                                                4.3
# 2                                                5.4
# 3                                                4.2
# 4                                                8.7
#
#   Percent!!SEX AND AGE!!Total population!!10 to 14 years  \
# 0                                                  5
# 1                                                5.8
# 2                                                6.1
# 3                                                6.2
# 4                                                7.3
#
#   Percent!!SEX AND AGE!!Total population!!15 to 19 years  \
# 0                                                  6
# 1                                                4.3
# 2                                                4.3
# 3                                                6.9
# 4                                                2.4
#
#   Percent!!SEX AND AGE!!Total population!!20 to 24 years  ...  \
# 0                                                4.5      ...
# 1                                                7.3      ...
# 2                                                6.8      ...
# 3                                                7.2      ...
# 4                                                6.3      ...
#
#   Percent!!HISPANIC OR LATINO AND RACE!!Total population!!Not Hispanic or Latino!!Two or More Races  \
# 0                                                4.2
# 1                                                  6
# 2                                                1.4
# 3                                                1.6
# 4                                                1.6
#
#   Percent!!HISPANIC OR LATINO AND RACE!!Total population!!Not Hispanic or Latino!!Two or More Races!!Two races including Some Other Race  \
# 0                                                  0
# 1                                                  1
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#   Percent!!HISPANIC OR LATINO AND RACE!!Total population!!Not Hispanic or Latino!!Two or More Races!!Two races excluding Some Other Race, and three or more races  \
# 0                                                4.2
# 1                                                  5
# 2                                                1.4
# 3                                                1.6
# 4                                                1.6
#
#   Percent!!Total housing units  \
# 0                          (X)
# 1                          (X)
# 2                          (X)
# 3                          (X)
# 4                          (X)
#
#   Percent!!CITIZEN, VOTING AGE POPULATION!!Citizen, 18 and over population  \
# 0                                               3106
# 1                                               3252
# 2                                               2459
# 3                                               2224
# 4                                               1552
#
#   Percent!!CITIZEN, VOTING AGE POPULATION!!Citizen, 18 and over population!!Male  \
# 0                                               46.5
# 1                                               52.4
# 2                                               46.8
# 3                                               54.9
# 4                                                 45
#
#   Percent!!CITIZEN, VOTING AGE POPULATION!!Citizen, 18 and over population!!Female  \
# 0                                               53.5
# 1                                               47.6
# 2                                               53.2
# 3                                               45.1
# 4                                                 55
#
#                       geometry     INTPTLAT      INTPTLON
# 0  POINT (-118.29299 34.25947)  +34.2594737  -118.2929869
# 1  POINT (-118.29015 34.26772)  +34.2677213  -118.2901465
# 2  POINT (-118.28163 34.25161)  +34.2516083  -118.2816328
# 3  POINT (-118.29258 34.25433)  +34.2543290  -118.2925767
# 4  POINT (-118.28853 34.25135)  +34.2513519  -118.2885261
#
# [5 rows x 95 columns]

# %% [markdown]
# Drop columns that I am not currently interested in

# %%
columns_to_drop = [col for col in gdf.columns if col.startswith('Margin of Error')]
gdf = gdf.drop(columns=columns_to_drop)
columns_to_drop = [col for col in gdf.columns if col.startswith('Estimate')]
gdf = gdf.drop(columns=columns_to_drop)
columns_to_drop = [col for col in gdf.columns if col.startswith('Percent Margin')]
gdf = gdf.drop(columns=columns_to_drop)

# %% [markdown]
# Folium map with a point for every tract

# %%
import folium

gdf_trim = gdf.dropna()

m = folium.Map()

for index, row in gdf_trim.iterrows():
    tooltip_text = 'Census Tract ' + str(row['NAME'])
    folium.Marker(
        [row.INTPTLAT,row.INTPTLON], 
        tooltip=tooltip_text,
    ).add_to(m)
    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d600d784cabb12a1e542f93b4493fb4f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d600d784cabb12a1e542f93b4493fb4f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d600d784cabb12a1e542f93b4493fb4f = L.map(
#                 &quot;map_d600d784cabb12a1e542f93b4493fb4f&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cf95aec0568b6fec7d68ecd75147409c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_cf95aec0568b6fec7d68ecd75147409c.addTo(map_d600d784cabb12a1e542f93b4493fb4f);
#
#
#             var marker_d39907fcb3c6c7c607a1f67d0c97063e = L.marker(
#                 [34.2594737, -118.2929869],
#                 {}
#             ).addTo(map_d600d784cabb12a1e542f93b4493fb4f);
#
#
#             marker_d39907fcb3c6c7c607a1f67d0c97063e.bindTooltip(
#                 `&lt;div&gt;
#                      Census Tract 1011.10
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_eeff5f77b6e08acba0d3a25b56b49437 = L.marker(
#                 [34.2677213, -118.2901465],
#                 {}
#             ).addTo(map_d600d784cabb12a1e542f93b4493fb4f);
#
#
#             marker_eeff5f77b6e08acba0d3a25b56b49437.bindTooltip(
#                 `&lt;div&gt;
#                      Census Tract 1011.22
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9eb97f6ad923dbb4c3aed1939e9dfabd = L.marker(
#                 [34.2516083, -118.2816328],
#                 {}
#             ).addTo(map_d600d784cabb12a1e542f93b4493fb4f);
#
#
#             marker_9eb97f6ad923dbb4c3aed1939e9dfabd.bindTooltip(
#                 `&lt;div&gt;
#                      Census Tract 1012.20
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_fb1e953bf02f279f5e0cb6829230aa03 = L.marker(
#                 [34.254329, -118.2925767],
#                 {}
#             ).addTo(map_d600d784cabb12a1e542f93b4493fb4f);
#
#
#             marker_fb1e953bf02f279f5e0cb6829230aa03.bindTooltip(
#                 `&lt;div&gt;
#                      Census Tract 1012.21
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8059e56cb1d637096d6eb1ceb073768a = L.marker(
#                 [34.2513519, -118.2885261],
#                 {}
#             ).addTo(map_d600d784cabb12a1e542f93b4493fb4f);
#
#
#             marker_8059e56cb1d637096d6eb1ceb073768a.bindTooltip(
#                 `&lt;div&gt;
#                      Census Tract 1012.22
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c62cdb5f4df09815dc14cc82189686ab = L.marker(
#                 [34.2250792, -118.354188],
#                 {}
#             ).addTo(map_d600d784cabb12a1e542f93b4493fb4f);
#
#
#             marker_c62cdb5f4df09815dc14cc82189686ab.bindTooltip(
#                 `&lt;div&gt;
#                      Census Tract 1021.03
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_95e3824c03041845fe736b5020f4bb99 = L.marker(
#                 [34.2161873, -118.3453981],
#                 {}
#             ).addTo(map_d600d784cabb12a1e542f93b4493fb4f);
#
#
#             marker_95e3824c03041845fe736b5020f4bb99.bindTooltip(
#                 `&lt;div&gt;
#                      Census Tract 1021.04
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_eb1dd6c0057f82c907775766ec4af2bf = L.marker(
#                 [34.209876, -118.3492653],
#                 {}
#             ).addTo(map_d600d784cabb12a1e542f93b4493fb4f);
#
#
#             marker_eb1dd6c0057f82c907775766ec4af2bf.bindTooltip(
#                 `&lt;div&gt;
#                      Census Tract 1021.05
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e062c330c26ed1e0ff32c95b56e5cfc3 = L.marker(
#                 [34.2409052, -118.3395988],
#                 {}
#             ).addTo(map_d600d784cabb12a1e542f93b4493fb4f);
#
#
#             marker_e062c330c26ed1e0ff32c95b56e5cfc3.bindTooltip(
#                 `&lt;div&gt;
#                      Census Tract 1021.07
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3d59e24e50179a616c58199a7c093de3 = L.marker(
#                 [34.2732407, -118.3078874],
#                 {}
#             ).addTo(map_d600d784cabb12a1e

# %% [markdown]
# Basic plots making sure the variables work

# %%
gdf_trim[["Percent!!SEX AND AGE!!Total population!!Male"]].plot()
gdf_trim[["Percent!!SEX AND AGE!!Total population!!Under 5 years"]].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 3
#       1 gdf_trim[["Percent!!SEX AND AGE!!Total population!!Male"]].plot()
#       2 gdf_trim[["Percent!!SEX AND AGE!!Total population!!Under 5 years"]].plot()
# ----> 3 gdf_trim[["Percent!!SEX AND AGE!!Total population!!65 years and over"]].plot()
#
# File /opt/conda/lib/python3.11/site-packages/pandas/plotting/_core.py:1031, in PlotAccessor.__call__(self, *args, **kwargs)
#    1028             label_name = label_kw or data.columns
#    1029             data.columns = label_name
# -> 1031 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File /opt/conda/lib/python3.11/site-packages/pandas/plotting/_matplotlib/core.py:451, in MPLPlot.generate(self)
#     449 def generate(self) -> None:
#     450     self._args_adjust()
# --> 451     self._compute_plot_data()
#     452     self._setup_subplots()
#     453     self._make_plot()
#
# File /opt/conda/lib/python3.11/site-packages/pandas/plotting/_matplotlib/core.py:636, in MPLPlot._compute_plot_data(self)
#     634 # no non-numeric frames or series allowed
#     635 if is_empty:
# --> 636     raise TypeError("no numeric data to plot")
#     638 self.data = numeric_data.apply(self._convert_to_ndarray)
#
# TypeError: no numeric data to plot
